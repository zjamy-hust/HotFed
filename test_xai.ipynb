# %%
# %run ./xai.py
# Out:
# assetpath /workspace/externalhome/XAI/HotFed/assets/folder
# /workspace/externalhome/XAI/HotFed/assets/folder/9.jpg
# predicted_asset bird Truth bird
# mask_im_name 9_mask.png
# pixelnum_all 870
# in mask pixelnum 173 870 0.19885057471264367
# out mask pixelnum 404 2202 0.18346957311534967
# /workspace/externalhome/XAI/HotFed/assets/folder/15.jpg
# predicted_asset dog Truth dog
# mask_im_name 15_mask.png
# pixelnum_all 924
# in mask pixelnum 137 924 0.14826839826839827
# out mask pixelnum 1 2148 0.0004655493482309125
# /workspace/externalhome/XAI/HotFed/assets/folder/4.jpg
# predicted_asset bird Truth bird
# mask_im_name 4_mask.png
# pixelnum_all 1434
# in mask pixelnum 198 1434 0.13807531380753138
# out mask pixelnum 40 1638 0.02442002442002442
# /workspace/externalhome/XAI/HotFed/assets/folder/21.jpg
# predicted_asset car Truth car
# mask_im_name 21_mask.png
# pixelnum_all 852
# in mask pixelnum 95 852 0.11150234741784038
# out mask pixelnum 116 2220 0.05225225225225225
# /workspace/externalhome/XAI/HotFed/assets/folder/20.jpg
# predicted_asset cat Truth dog
# mask_im_name 20_mask.png
# pixelnum_all 1452
# in mask pixelnum 125 1452 0.08608815426997245
# out mask pixelnum 25 1620 0.015432098765432098
# /workspace/externalhome/XAI/HotFed/assets/folder/14.jpg
# predicted_asset bird Truth bird
# mask_im_name 14_mask.png
# pixelnum_all 912
# in mask pixelnum 130 912 0.1425438596491228
# out mask pixelnum 296 2160 0.13703703703703704
# /workspace/externalhome/XAI/HotFed/assets/folder/29.jpg
# predicted_asset car Truth truck
# mask_im_name 29_mask.png
# pixelnum_all 984
# in mask pixelnum 132 984 0.13414634146341464
# out mask pixelnum 287 2088 0.13745210727969348
# /workspace/externalhome/XAI/HotFed/assets/folder/23.jpg
# predicted_asset cat Truth cat
# mask_im_name 23_mask.png
# pixelnum_all 1359
# in mask pixelnum 19 1359 0.013980868285504048
# out mask pixelnum 116 1713 0.06771745475773497
# /workspace/externalhome/XAI/HotFed/assets/folder/28.jpg
# predicted_asset frog Truth frog
# mask_im_name 28_mask.png
# pixelnum_all 792
# in mask pixelnum 28 792 0.03535353535353535
# out mask pixelnum 291 2280 0.12763157894736843
# /workspace/externalhome/XAI/HotFed/assets/folder/10.jpg
# predicted_asset ship Truth ship
# mask_im_name 10_mask.png
# pixelnum_all 621
# in mask pixelnum 91 621 0.14653784219001612
# out mask pixelnum 132 2451 0.05385556915544676
# /workspace/externalhome/XAI/HotFed/assets/folder/1.jpg
# predicted_asset horse Truth horse
# mask_im_name 1_mask.png
# pixelnum_all 1704
# in mask pixelnum 212 1704 0.12441314553990611
# out mask pixelnum 154 1368 0.11257309941520467
# /workspace/externalhome/XAI/HotFed/assets/folder/17.jpg
# predicted_asset plane Truth plane
# mask_im_name 17_mask.png
# pixelnum_all 990
# in mask pixelnum 79 990 0.0797979797979798
# out mask pixelnum 453 2082 0.21757925072046108
# /workspace/externalhome/XAI/HotFed/assets/folder/5.jpg
# predicted_asset plane Truth plane
# mask_im_name 5_mask.png
# pixelnum_all 1554
# in mask pixelnum 248 1554 0.15958815958815958
# out mask pixelnum 184 1518 0.12121212121212122
# /workspace/externalhome/XAI/HotFed/assets/folder/25.jpg
# predicted_asset deer Truth deer
# mask_im_name 25_mask.png
# pixelnum_all 786
# in mask pixelnum 41 786 0.05216284987277354
# out mask pixelnum 239 2286 0.10454943132108487
# /workspace/externalhome/XAI/HotFed/assets/folder/3.jpg
# predicted_asset plane Truth bird
# mask_im_name 3_mask.png
# pixelnum_all 564
# in mask pixelnum 70 564 0.12411347517730496
# out mask pixelnum 393 2508 0.15669856459330145
# /workspace/externalhome/XAI/HotFed/assets/folder/26.jpg
# predicted_asset deer Truth deer
# mask_im_name 26_mask.png
# pixelnum_all 807
# in mask pixelnum 111 807 0.137546468401487
# out mask pixelnum 142 2265 0.06269315673289183
# /workspace/externalhome/XAI/HotFed/assets/folder/22.jpg
# predicted_asset car Truth car
# mask_im_name 22_mask.png
# pixelnum_all 810
# in mask pixelnum 97 810 0.11975308641975309
# out mask pixelnum 321 2262 0.1419098143236074
# /workspace/externalhome/XAI/HotFed/assets/folder/7.jpg
# predicted_asset deer Truth horse
# mask_im_name 7_mask.png
# pixelnum_all 1170
# in mask pixelnum 210 1170 0.1794871794871795
# out mask pixelnum 97 1902 0.05099894847528917
# /workspace/externalhome/XAI/HotFed/assets/folder/2.jpg
# predicted_asset ship Truth ship
# mask_im_name 2_mask.png
# pixelnum_all 1782
# in mask pixelnum 267 1782 0.14983164983164984
# out mask pixelnum 227 1290 0.175968992248062
# /workspace/externalhome/XAI/HotFed/assets/folder/11.jpg
# predicted_asset plane Truth ship
# mask_im_name 11_mask.png
# pixelnum_all 1530
# in mask pixelnum 144 1530 0.09411764705882353
# out mask pixelnum 189 1542 0.122568093385214
# /workspace/externalhome/XAI/HotFed/assets/folder/24.jpg
# predicted_asset cat Truth cat
# mask_im_name 24_mask.png
# pixelnum_all 1773
# in mask pixelnum 142 1773 0.08009024252679076
# out mask pixelnum 177 1299 0.13625866050808313
# /workspace/externalhome/XAI/HotFed/assets/folder/8.jpg
# predicted_asset truck Truth truck
# mask_im_name 8_mask.png
# pixelnum_all 1584
# in mask pixelnum 231 1584 0.14583333333333334
# out mask pixelnum 102 1488 0.06854838709677419
# /workspace/externalhome/XAI/HotFed/assets/folder/27.jpg
# predicted_asset frog Truth frog
# mask_im_name 27_mask.png
# pixelnum_all 1431
# in mask pixelnum 198 1431 0.13836477987421383
# out mask pixelnum 122 1641 0.07434491163924437
# /workspace/externalhome/XAI/HotFed/assets/folder/19.jpg
# predicted_asset dog Truth dog
# mask_im_name 19_mask.png
# pixelnum_all 1275
# in mask pixelnum 144 1275 0.11294117647058824
# out mask pixelnum 75 1797 0.041736227045075125
# /workspace/externalhome/XAI/HotFed/assets/folder/16.jpg
# predicted_asset ship Truth ship
# mask_im_name 16_mask.png
# pixelnum_all 1338
# in mask pixelnum 135 1338 0.10089686098654709
# out mask pixelnum 255 1734 0.14705882352941177
# /workspace/externalhome/XAI/HotFed/assets/folder/6.jpg
# predicted_asset dog Truth dog
# mask_im_name 6_mask.png
# pixelnum_all 2307
# in mask pixelnum 293 2307 0.1270047680970958
# out mask pixelnum 74 765 0.09673202614379085
# /workspace/externalhome/XAI/HotFed/assets/folder/13.jpg
# predicted_asset ship Truth ship
# mask_im_name 13_mask.png
# pixelnum_all 1317
# in mask pixelnum 112 1317 0.085041761579347
# out mask pixelnum 281 1755 0.16011396011396012
# /workspace/externalhome/XAI/HotFed/assets/folder/18.jpg
# predicted_asset horse Truth horse
# mask_im_name 18_mask.png
# pixelnum_all 1740
# in mask pixelnum 84 1740 0.04827586206896552
# out mask pixelnum 111 1332 0.08333333333333333
# /workspace/externalhome/XAI/HotFed/assets/folder/30.jpg
# predicted_asset cat Truth cat
# mask_im_name 30_mask.png
# pixelnum_all 1932
# in mask pixelnum 116 1932 0.060041407867494824
# out mask pixelnum 116 1140 0.10175438596491228
# /workspace/externalhome/XAI/HotFed/assets/folder/12.jpg
# predicted_asset bird Truth bird
# mask_im_name 12_mask.png
# pixelnum_all 798
# in mask pixelnum 137 798 0.17167919799498746
# out mask pixelnum 80 2274 0.03518029903254178
# in_mask_acc_mean 0.11487760891307866 out_mask_acc_mean 0.10038485773043115 XAI ACC 0.5333333333333333
# a 0.11487760891307866 b 0.10038485773043115 c 0.5333333333333333

# %% [markdown]
# !pwd

# %%
# %run ./fedxai.py --verbose 1 --model=resnet18 --dataset=cifar10 --gpu=3 --iid=1 --epochs=20 --lr=0.01 --local_bs=128 --local_ep=50 --num_users=16
