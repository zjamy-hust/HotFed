# %%
# %run ./xai.py
# Out:
# Files already downloaded and verified
# /workspace/externalhome/XAI/HotFed/assets/folder
# /workspace/externalhome/XAI/HotFed/assets/folder/9.jpg
# predicted_temp bird Truth bird
# mask_im_name 9_mask.png
# pixelnum_all 870
# in mask pixelnum 190 870 0.21839080459770116
# out mask pixelnum 364 2202 0.16530426884650318
# /workspace/externalhome/XAI/HotFed/assets/folder/15.jpg
# predicted_temp dog Truth dog
# mask_im_name 15_mask.png
# pixelnum_all 924
# in mask pixelnum 60 924 0.06493506493506493
# out mask pixelnum 249 2148 0.11592178770949721
# /workspace/externalhome/XAI/HotFed/assets/folder/4.jpg
# predicted_temp bird Truth bird
# mask_im_name 4_mask.png
# pixelnum_all 1434
# in mask pixelnum 93 1434 0.06485355648535565
# out mask pixelnum 252 1638 0.15384615384615385
# /workspace/externalhome/XAI/HotFed/assets/folder/21.jpg
# predicted_temp car Truth car
# mask_im_name 21_mask.png
# pixelnum_all 852
# in mask pixelnum 70 852 0.08215962441314555
# ...

# %%
# !pwd
# Out:
# /workspace/externalhome/XAI/HotFed
