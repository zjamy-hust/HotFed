# %%
# %run pretrain_rot.py --gpu 3 --dataset 'cifar10' --arch resnet18
# Out:
# Creating folder: log/cifar10_resnet18_CE_None_exp_0.01_pretrain_rot
# Creating folder: ./checkpoint/cifar10_resnet18_CE_None_exp_0.01_pretrain_rot
# Use GPU:  {3}  for training
# ===> Creating model '{args.arch}'
# /workspace/mytest/FederatedLearning/unsupervised_pretrain/pretrain_rot.py:68: UserWarning: You have chosen a specific GPU. This will completely disable data parallelism.
#   main_worker(args.gpu, args)
# Files already downloaded and verified
# Files already downloaded and verified
# The  0  epoch
# Epoch: [0][0/391], lr: 0.00200	Time 0.619 (0.619)	Data 0.187 (0.187)	Loss 2.5702 (2.5702)	Prec@1 2.344 (2.344)
# Epoch: [0][10/391], lr: 0.00200	Time 0.042 (0.094)	Data 0.000 (0.017)	Loss 1.2381 (1.5131)	Prec@1 42.969 (31.605)
# Epoch: [0][20/391], lr: 0.00200	Time 0.040 (0.069)	Data 0.000 (0.009)	Loss 1.2170 (1.4047)	Prec@1 44.531 (37.351)
# Epoch: [0][30/391], lr: 0.00200	Time 0.040 (0.059)	Data 0.000 (0.006)	Loss 1.3269 (1.3249)	Prec@1 42.188 (40.953)
# ...
