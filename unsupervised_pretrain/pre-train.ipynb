# %%
# %run pretrain_rot.py --gpu 3 --dataset 'cifar100' --arch resnet18
# Out:
# Creating folder: log
# Creating folder: ./checkpoint
# Creating folder: log/cifar10_resnet18_CE_None_exp_0.01_pretrain_rot
# Creating folder: ./checkpoint/cifar10_resnet18_CE_None_exp_0.01_pretrain_rot
# Use GPU:  {3}  for training
# ===> Creating model '{args.arch}'
# /workspace/externalhome/XAI/HotFed/unsupervised_pretrain/pretrain_rot.py:86: UserWarning: You have chosen a specific GPU. This will completely disable data parallelism.
#   warnings.warn('You have chosen a specific GPU. This will completely disable data parallelism.')
# ...
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ../data/cifar/cifar-10-python.tar.gz to ../data/cifar
# Files already downloaded and verified
# The  0  epoch
# Epoch: [0][0/391], lr: 0.00200	Time 5.412 (5.412)	Data 0.196 (0.196)	Loss 2.3456 (2.3456)	Prec@1 0.781 (0.781)
# Epoch: [0][10/391], lr: 0.00200	Time 0.035 (0.525)	Data 0.000 (0.018)	Loss 1.2783 (1.4881)	Prec@1 46.094 (29.759)
# ...
